# %% [markdown]
# ![Screen%20Shot%202017-11-02%20at%2010.28.31%20PM.png](attachment:Screen%20Shot%202017-11-02%20at%2010.28.31%20PM.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.linspace(-np.pi, np.pi)
lhs= np.exp(1j*x)
rhs = np.cos(x) + 1j*np.sin(x)
print(sum(lhs==rhs) == len(x))
# Out:
# True

# %%
for p in np.exp(1j*x):
    plt.polar([0, np.angle(p)],[0, abs(p)], marker = "o")
plt.show()
